# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejandroPSJ2/DataMining_c1/blob/main/Clase1_example2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm
url = 'https://raw.githubusercontent.com/AlejandroPSJ2/DataMining_c1/main/Clase1_example2.csv'
df = pd.read_csv(url,sep=';')

# %%
df.head()
# Out:
#    Week  PRICE 12PK  PRICE 18PK  PRICE 30PK  CASES 12PK  CASES 18PK  \
# 0     1       19.98       14.10       15.19       223.5         439
# 1     2       19.98       18.65       15.19       215.0          98
# 2     3       19.98       18.65       13.87       227.5          70
# 3     4       19.98       18.65       12.83       244.5          52
# 4     5       19.98       18.65       13.16       313.5          64
#
#    CASES 30PK
# 0       55.00
# 1       66.75
# 2      242.00
# 3      488.50
# 4      308.75

# %%
Y = df['CASES 30PK']
X = df['PRICE 30PK']
X = sm.add_constant(X)

# %%
mod = sm.OLS(Y,X)
res = mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             CASES 30PK   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     93.22
# Date:                Sat, 09 Sep 2023   Prob (F-statistic):           5.17e-13
# Time:                        07:16:59   Log-Likelihood:                -294.71
# No. Observations:                  52   AIC:                             593.4
# Df Residuals:                      50   BIC:                             597.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1887.2558    178.648     10.564      0.000    1528.431    2246.081
# ...
